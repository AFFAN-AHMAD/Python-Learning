# %% [markdown]
# #  LLM

# %%
# import os
# from openai import OpenAI

# # Initialize the OpenAI client with Kimi's base URL
# client = OpenAI(
#     api_key=os.environ.get('KIMI_API_KEY'),
#     base_url="https://api.moonshot.ai/v1"
# )
# print()
# # Create a chat completion request
# completion = client.chat.completions.create(
#     model="kimi-k3",
#     messages=[
#         {"role": "user", "content": "Bro, give me a fun fact"},
        
#     ]
# )

# # Print the text response
# print(completion.choices[0].message.content)
# Out:
# Alright, here's one that messes with people's sense of time:
#
# **Cleopatra lived closer in time to the Moon landing than to the construction of the Great Pyramid of Giza.**
#
# The pyramid was built around 2560 BCE, Cleopatra was alive around 30 BCE, and the Moon landing happened in 1969. So she's about 2,500 years removed from the pyramid, but only ~2,000 years from Neil Armstrong. Ancient Egypt was ancient even to ancient Egyptians. 🤯
#
# Want another one?

# %%
import os
from langchain_openai import ChatOpenAI
llm_openai = ChatOpenAI(
    model='kimi-k2.6', 
    api_key=os.environ.get('KIMI_API_KEY'),
    base_url="https://api.moonshot.ai/v1"
    )
llm_openai.invoke("Bro, give me a fun fact")
# Out:
# AIMessage(content="Bro, wombats poop cubes. Like actual, legit cubes. \n\nScientists figured out it's because their intestines have weirdly uneven wall elasticity that shapes the poop into little geometric blocks as it dries. They stack 'em up like Lego to mark their territory and since they're cubes, they don't roll away. \n\nNature is wild. 🧊💩", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 294, 'prompt_tokens': 14, 'total_tokens': 308, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 221, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'kimi-k2.6', 'system_fingerprint': None, 'id': 'chatcmpl-6a632f5904730fd469325402', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f9370-f0c4-7661-8002-24674cc94d76-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 294, 'total_tokens': 308, 'input_token_details': {}, 'output_token_details': {'reasoning': 221}})
